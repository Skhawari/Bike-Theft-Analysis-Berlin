# %% [raw]
# ---
# title: Stolen bikes and amount of damage
# description: Shows the amount of damage of stolen bikes in different districts.
# show-code: False
# params:
#     schaden:
#         input: select
#         label: select what you want to know
#         value: schadenhöhe in jeder Bezirk
#         choices: [schadenhöhe in jeder Bezirk, teuersten, billigsten]
#     limit:
#         input: slider
#         label: select limit
#         value: 5
#         min: 1
#         max: 12
# ---

# %%
schaden = "schadenhöhe in jeder Bezirk"
limit = 5

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

def connect_to_database():
    # Verbindung zur Datenbank herstellen
    conn = psycopg2.connect(database="fahrraddiebstahlinberlin", user='postgres', password='015775570018', host='127.0.0.1', port='5432')
    return conn

if __name__ == '__main__':
    
    conn = connect_to_database()
    engine = create_engine('postgresql://postgres:015775570018@localhost:5432/fahrraddiebstahlinberlin')

    if schaden == "schadenhöhe in jeder Bezirk":
        conn = connect_to_database()  #Für alle Uhrzeiten und Bezirken
        query = '''
        SELECT b.gemeinde_name, SUM(fd.schadenshoehe) AS schadenhoehe
        FROM bezirksgrenz b
        JOIN lor_planung lp ON b.gemeinde_schluessel = lp.bez
        JOIN fahrraddieb fd ON lp.plr_id = fd.lor
        GROUP BY b.gemeinde_name
        ORDER BY schadenhoehe DESC;
        '''

        df = pd.read_sql_query(query, engine)
        conn.close()

        gdf = gpd.read_file("bezirksgrenzen.geojson")

        gdf['Gemeinde_name'] = gdf['Gemeinde_name'].str.strip()
        df['gemeinde_name'] = df['gemeinde_name'].str.strip()

        merged_gdf = gdf.merge(df, left_on="Gemeinde_name", right_on="gemeinde_name", how="left")

        fig, ax = plt.subplots(figsize=(12, 8))
        merged_gdf.plot(column='schadenhoehe', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
        plt.title('Schadenhöhe nach Bezirk')
        plt.axis('off')
        plt.show()       
            
    else:
        conn = connect_to_database()
        cur = conn.cursor()
        
        if schaden == "teuersten":
            select = "MAX"
            absteigend = "DESC"
        else:
            select = "MIN"
            absteigend = "ASC"
        
        query = """
        SELECT b.gemeinde_name, """ + select + """(fd.schadenshoehe) AS schadenshoehe
        FROM bezirksgrenz b
        JOIN lor_planung lp ON b.gemeinde_schluessel = lp.bez
        JOIN fahrraddieb fd ON lp.plr_id = fd.lor
        WHERE fd.schadenshoehe IS NOT NULL and fd.schadenshoehe > 1
        GROUP BY b.gemeinde_name
        HAVING """ + select + """(fd.schadenshoehe) > 2
        ORDER BY schadenshoehe """ + absteigend + """ LIMIT """ + str(limit) + ";"
        
        cur.execute(query)
        data = cur.fetchall()

        print("Bezirk" )
        for row in data:
            print(row[0] , int(row[1]))
